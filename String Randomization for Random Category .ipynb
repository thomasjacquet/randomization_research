# %%
import pandas as pd
from faker import Faker
from random import randint
from random_username.generate import generate_username
occupations = pd.read_csv('occupation_title.csv')
us_cities = pd.read_csv('us_cities.csv')
random_addresses = pd.read_csv('random_addresses.csv')
us_cities['ZIP'] = us_cities['ZIP'].astype('object')

RECORD_COUNT = 50000
fake = Faker()
name_list = []
email_list = []

def name_method(full_name):
    provider_list = ['@gmail.com','@outlook.com','@hotmail.com','@yahoo.com','@gmx.com','@icloud.com',
     '@aol.com','@zoho.com','@aim.com','@protonmail.com','@gmx.us','@yandex.com']
    name_method1 = (full_name+provider_list[randint(0,(randint(2,11)))]).lower().replace(" ","_")
    name_method2 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:3].lower())).replace(" ",".")
    name_method3 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:1].lower())).replace(" ",".")
    name_method4 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(full_name).lower(),str((full_name.split(" ")[1])+" "+str(full_name.split(" ")[0])).lower()).replace(" ","_")
    name_method5 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(full_name).lower(),str((full_name.split(" ")[1])+" "+str(full_name.split(" ")[0])).lower()).replace(" ",".")
    name_method6 = (str(full_name.split(" ")[0]).lower()+str(randint(100,999))+str(provider_list[randint(0,(randint(2,11)))]))
    name_method7 = (full_name+str(randint(100,999))).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:1].lower())).replace(" ","")+str(provider_list[randint(0,(randint(2,11)))])
    name_method8 = (str(*generate_username(1))+str(provider_list[randint(0,(randint(2,11)))])).lower()
    name_method = [name_method1,name_method2,name_method3,name_method4,name_method5,name_method6,name_method7,name_method8]
    return name_method[randint(0,7)]



email ={'Name': [], 'Email' : [],'Occupation': [],'Address':[]}
for i in range(10000):
    name = fake.name()
    occupation = occupations['Title'][randint(0,1221)]
    email['Name'].append(str(name))
    email['Email'].append(name_method(name)) 
    email['Occupation'].append(occupation.title())
    address1 = fake.street_address()
    address2 = random_addresses['Address'][randint(0,49999)]
    address = [address1,address2]
    address = address[randint(0,1)]
    email['Address'].append(address)

email = pd.DataFrame(email)

dict_city = {'ZIP': [],'City': [],'County': [],'State': []}
cities = pd.DataFrame(dict_city)        

for i in range(len(email)):
        city_method1 = randint(0,10)
        city_method2 = randint(0,75)
        city_method3 = randint(0,150)
        city_method4 = randint(0,150)
        city_method5 = randint(0,3000)
        city_method6 = randint(0,10)
        city_method7 = randint(0,75)
        city_method8 = randint(0,28334)
        city_method = [city_method1,city_method2,city_method3,city_method4,city_method5,city_method6,city_method7]
        x = city_method[randint(0,6)]
        cities = pd.concat([cities, us_cities.iloc[(int(x)):(int(x)+1)]],axis=0)
        #if len(str(cities['ZIP'][i])) <= 4:
                #cities['ZIP'][i] = str(cities['ZIP'][i]).lstrip().replace(str(cities['ZIP'][i]), str(0)+str(cities['ZIP'][i]))
        #cities['ZIP'][i] = str(cities['ZIP'][i]).replace(str(cities['ZIP'][i]), (str(cities['ST'][i])+' '+str(cities['ZIP'][i])))
cities = cities.reset_index()
cities = cities.drop(['index'],axis = 1)
email =  pd.concat([email,cities],axis=1)
email
    

    
      





#name_method = [name_method1,name_method2,name_method3,name_method4,name_method5,name_method6,name_method7,name_method8]

#first_name = str(name_list[5].split(" ")[0]).lower()
#nickname = str(name_list[5].split(" ")[0][0:3].lower())

#email = name_method[randint(0,7)]

#email = email
#email = email



email = pd.DataFrame(email)

for i in range(len(email['ZIP'])):
    if len(str(email['ZIP'][i])) <= 4:
                email['ZIP'][i] = str(email['ZIP'][i]).lstrip().replace(str(email['ZIP'][i]), str(0)+str(email['ZIP'][i]))
    email['ZIP'][i] = str(email['ZIP'][i]).lstrip().replace(str(email['ZIP'][i]), (str(email['ST'][i])+' '+str(email['ZIP'][i])))
    
email = email.drop(['ST'],axis=1)

email.sample(45)
# Out:
#                         Name                          Email  \
# 8176          Lauren Rollins     lauren_rollins@hotmail.com
# 9819         Rebecca Burgess            r.burgess@gmail.com
# 56              Linda Prince       linda_prince@outlook.com
# 2651       Ms. Bethany Carey   ms._bethany_carey@icloud.com
# 4533          Hayley Shelton          hayley168@outlook.com
# 8445             Rita Gibson          rit.gibson@yandex.com
# 8018         Melissa Goodwin            mgoodwin100@aol.com
# 4771          Nicole Collins       collins_nicole@gmail.com
# 9384          Jonathan Mejia        jonathan910@hotmail.com
# 1654          Melissa Nguyen           m.nguyen@outlook.com
# 9592           Sierra Walker           sie.walker@gmail.com
# 5269             John Gentry          joh.gentry@icloud.com
# 9126           Julie Simpson      simpson.julie@hotmail.com
# 5687         Joshua Gonzalez          joshua764@hotmail.com
# 7639           Jim Velazquez        j.velazquez@hotmail.com
# ...

# %%
email.sample(45)
# Out:
#                        Name                         Email  \
# 12272          Peter Taylor            p.taylor@gmail.com
# 46504           Marie Brock       brock.marie@hotmail.com
# 22587  Dr. Melissa Brown MD       zestyrhino9@hotmail.com
# 23286         Chris Mcguire       cmcguire950@outlook.com
# 37286         Richard Hayes           dearlard3@gmail.com
# 33034          Bobby Reilly        bobby_reilly@yahoo.com
# 18394        Dylan Caldwell    pleasedtoucan7@outlook.com
# 43513      Richard Gallegos        r.gallegos@hotmail.com
# 43199         Dylan Johnson       johnson_dylan@yahoo.com
# 46958         Timothy Knapp         tknapp877@outlook.com
# 12025        Kristine Lopez           kristine901@aol.com
# 29036            Laura Lane              l.lane@gmail.com
# 13980          Richard Kane      excludedbuzzard0@aim.com
# 44114         Marcus Adkins          mar.adkins@gmail.com
# 11850            Becky Owen             b.owen@icloud.com
# ...

# %%
us_cities = pd.read_csv('us_cities.csv')
random_addresses = pd.read_csv('random_addresses.csv')
#random_contacts = pd.concat([random1,random2,random3,random4,random5,random6,random7,random8,random9])
read_pipe = ['random_contacts1.csv','random_contacts2.csv','random_contacts3.csv','random_contacts4.csv','random_contacts5.csv','random_contacts6.csv','random_contacts7.csv','random_contacts8.csv','random_contacts9.csv','random_contacts10.csv']
    
for i in range(len(read_pipe)):
    
    if int(i) == 0:
        random_contacts = pd.read_csv(read_pipe[i])
        random_contacts_cc = pd.read_csv(read_pipe[int(i+1)])
        random_contacts_final = pd.concat([random_contacts,random_contacts_cc])
    elif int(i) != 0 or int(i) != len(read_pipe):
        random_contacts = pd.read_csv(read_pipe[i])
        random_contacts_final = pd.concat([random_contacts_final, random_contacts],axis=0, ignore_index = True)
    else:
        break
        
    

    
random_contacts_final = random_contacts_final.sample(2200)
random_contacts_final
# Out:
#       First Name  Last Name  Gender        Phone        Education  \
# 846        Daryl   Phillips    Male  694-7358-25         Doctoral
# 1413         Max    Stevens    Male  524-2940-40           Master
# 1495      Carina     Brooks  Female  161-3041-18  Upper secondary
# 1346  Maximilian      Ellis    Male  852-5632-57  Lower secondary
# 822       Lyndon    Johnson    Male  058-0373-73         Bachelor
# ...          ...        ...     ...          ...              ...
# 182     Michelle     Howard  Female  803-7108-02         Bachelor
# 1468      Vivian      Brown  Female  623-4581-91          Primary
# 143       Carina     Tucker  Female  127-4960-16         Bachelor
# 1736     Melissa    Stevens  Female  619-6605-12         Bachelor
# 1498       Edwin  Armstrong    Male  006-7978-37           Master
#
#             Occupation  Salary Marital Status  Number of Children
# 846              Baker    4015         Single                   1
# ...

# %%
random_contacts_name = {'Name': []}
for x,y in zip(random_contacts_final['First Name'],random_contacts_final['Last Name']):
    full_name = (str(x)+' '+str(y))
    random_contacts_name['Name'].append(str(x)+' '+str(y))
random_contacts_name = pd.DataFrame(random_contacts_name)
random_contacts_final = pd.concat([random_contacts_final,random_contacts_name],axis=1)
random_contacts_final = random_contacts_final[['Name', 'Occupation','Education',
                          'Marital Status', 'Phone']]
random_contacts_final['Email'] = random_contacts_final['Name'].apply(name_method)
random_contacts_final
# Out:
#                   Name     Occupation        Education Marital Status  \
# 0       Daryl Phillips          Medic         Bachelor         Single
# 1          Max Stevens   Veterinarian           Master        Married
# 2        Carina Brooks      Scientist          Primary        Married
# 3     Maximilian Ellis    Fine Artist  Upper secondary         Single
# 4       Lyndon Johnson     Biochemist           Master         Single
# ...                ...            ...              ...            ...
# 2195   Michelle Howard  Social Worker         Doctoral        Married
# 2196      Vivian Brown     Accountant         Doctoral        Married
# 2197     Carina Tucker    Fine Artist          Primary        Married
# 2198   Melissa Stevens        Florist          Primary         Single
# 2199   Edwin Armstrong       Lecturer         Doctoral        Married
#
#             Phone                        Email
# 0     807-1740-17   phillips.daryl@hotmail.com
# ...

# %%
random_addresses['Address'][randint(0,49999)]
# Out:
# '611 Amber Viaduct                   '

# %%
address_list = {'Address':[]}
for i in range(len(random_contacts_final)):
        address1 = fake.street_address()
        address2 = random_addresses['Address'][randint(0,49999)]
        address = [address1,address2]
        address = address[randint(0,1)]
        address_list['Address'].append(address)

address_list = pd.DataFrame(address_list)
address_list = address_list.sample(2200)
address_list.sample(45)
# Out:
#                                    Address
# 1772  738 Cedar Forest
# 1802  107 W Pond Vale
# 285   232 E Chase
# 2074  64 Harvest Ranch
# 505                      034 Warren Canyon
# ...                                    ...
# 988                   01528 Charles Points
# 1622         7376 Williams Spurs Suite 180
# 1501  182 Sunny Blossom Alley
# 1042                   732 Catherine Shore
# 1174                 58620 Miller Crossing
#
# [2200 rows x 1 columns]

# %%
random_contacts_final = pd.concat([random_contacts_final,address_list],axis=1)
random_contacts_final
# Out:
#                   Name     Occupation        Education Marital Status  \
# 0          Carl Howard          Medic         Bachelor         Single
# 1       Martin Carroll   Veterinarian           Master        Married
# 2          Emma Bailey      Scientist          Primary        Married
# 3       Lenny Morrison    Fine Artist  Upper secondary         Single
# 4      Penelope Morgan     Biochemist           Master         Single
# ...                ...            ...              ...            ...
# 2195       Oscar Craig  Social Worker         Doctoral        Married
# 2196  Jasmine Richards     Accountant         Doctoral        Married
# 2197     Adele Elliott    Fine Artist          Primary        Married
# 2198   Charlotte Payne        Florist          Primary         Single
# 2199   Fenton Thompson       Lecturer         Doctoral        Married
#
#             Phone                      Email  \
# 0     807-1740-17      howard.carl@gmail.com
# ...

# %%
us_cities_zip = {'ZIP': []}
for x,y in zip(us_cities['ST'],us_cities['ZIP']):
    full_zip = (str(x)+' '+str(y))
    us_cities_zip['ZIP'].append(str(x)+' '+str(y))
us_cities_zip  = pd.DataFrame(us_cities_zip )
us_cities = us_cities.drop(['ZIP'], axis=1)
us_cities  = pd.concat([us_cities ,us_cities_zip ],axis=1)

us_cities = us_cities[['ZIP', 'City', 'County','State']]

# %%
dict_city = {'ZIP': [],'City': [],'County': [],'State': []}
cities = pd.DataFrame(dict_city)        
for i in range(len(random_contacts_final)):
        city_method1 = randint(0,10)
        city_method2 = randint(0,75)
        city_method3 = randint(0,150)
        city_method4 = randint(0,150)
        city_method5 = randint(0,3000)
        city_method6 = randint(0,10)
        city_method7 = randint(0,75)
        city_method8 = randint(0,28334)
        city_method = [city_method1,city_method2,city_method3,city_method4,city_method5,city_method6,city_method7]
        x = city_method[randint(0,6)]
        cities = pd.concat([cities, us_cities.iloc[(int(x)):(int(x)+1)]],axis=0)
cities = cities.reset_index()
cities = cities.drop(['index'],axis = 1)
random_contacts_final =  pd.concat([random_contacts_final,cities],axis=1)
random_contacts_final
# Out:
#                   Name     Occupation        Education Marital Status  \
# 0          Carl Howard          Medic         Bachelor         Single
# 1       Martin Carroll   Veterinarian           Master        Married
# 2          Emma Bailey      Scientist          Primary        Married
# 3       Lenny Morrison    Fine Artist  Upper secondary         Single
# 4      Penelope Morgan     Biochemist           Master         Single
# ...                ...            ...              ...            ...
# 2195       Oscar Craig  Social Worker         Doctoral        Married
# 2196  Jasmine Richards     Accountant         Doctoral        Married
# 2197     Adele Elliott    Fine Artist          Primary        Married
# 2198   Charlotte Payne        Florist          Primary         Single
# 2199   Fenton Thompson       Lecturer         Doctoral        Married
#
#             Phone                      Email  \
# 0     807-1740-17      howard.carl@gmail.com
# ...

# %%
random_contacts_final.sample(45)
# Out:
#                     Name         Occupation        Education Marital Status  \
# 1144       Byron Farrell           Engineer         Doctoral        Married
# 96        Frederick Hunt         Accountant  Lower secondary         Single
# 1302      Lyndon Johnson             Dancer  Upper secondary         Single
# 805        Kate Thompson            Insurer         Doctoral        Married
# 1923      Arianna Turner               Cook          Primary        Married
# 468       Julia Phillips   Graphic Designer         Doctoral         Single
# 1655         Elian Baker        Fine Artist         Bachelor         Single
# 781          Jacob Riley        Hairdresser         Doctoral         Single
# 159    Vincent Alexander       Archeologist  Upper secondary         Single
# 1296    Roland Alexander              Actor  Upper secondary         Single
# 1150   Frederick Hawkins          Historian  Upper secondary         Single
# ...

# %%
random_contacts_final = random_contacts_final.sample(45)
random_contacts_final.to_csv('random_contacts.csv')
random_contacts_final
# Out:
#                     Name         Occupation        Education Marital Status  \
# 833        Carina Miller         Astronomer  Lower secondary         Single
# 1432     Adelaide Foster         Astronomer         Bachelor        Married
# 1663        Jared Fowler              Lawer         Bachelor         Single
# 70          Blake Carter         Biochemist  Upper secondary        Married
# 965       Leonardo Payne          Historian           Master        Married
# 1302      Lyndon Johnson             Dancer  Upper secondary         Single
# 1727          Adam Payne   Fashion Designer  Lower secondary        Married
# 1987     Gianna Campbell             Driver  Upper secondary         Single
# 358       Bruce Harrison          Scientist  Lower secondary        Married
# 120          Henry Dixon             Driver         Bachelor         Single
# 323       Walter Farrell          Scientist          Primary        Married
# ...

# %%
def name_method(full_name):
    provider_list = ['@gmail.com','@outlook.com','@hotmail.com','@yahoo.com','@gmx.com','@icloud.com',
     '@aol.com','@zoho.com','@aim.com','@protonmail.com','@gmx.us','@yandex.com']
    name_method1 = (full_name+provider_list[randint(0,(randint(2,11)))]).lower().replace(" ","_")
    name_method2 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:3].lower())).replace(" ",".")
    name_method3 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:1].lower())).replace(" ",".")
    name_method4 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(full_name).lower(),str((full_name.split(" ")[1])+" "+str(full_name.split(" ")[0])).lower()).replace(" ","_")
    name_method5 = (full_name+str(provider_list[randint(0,(randint(2,11)))])).lower().replace(str(full_name).lower(),str((full_name.split(" ")[1])+" "+str(full_name.split(" ")[0])).lower()).replace(" ",".")
    name_method6 = (str(full_name.split(" ")[0]).lower()+str(randint(0,999))+str(provider_list[randint(0,(randint(2,11)))]))
    name_method7 = (full_name+str(randint(100,999))).lower().replace(str(str(full_name.split(" ")[0]).lower()),str(full_name.split(" ")[0][0:1].lower())).replace(" ","")+str(provider_list[randint(0,(randint(2,11)))])
    name_method8 = (str(*generate_username(1))+str(provider_list[randint(0,(randint(2,11)))])).lower()
    name_method = [name_method1,name_method2,name_method3,name_method4,name_method5,name_method6,name_method7,name_method8]
    return name_method[randint(0,7)]
first = str(input('First Name : ')).title()
last = str(input('Last Name : ')).title()
fabricated_name = str(str(first)+' '+str(last))
fabricated_email = name_method(fabricated_name)
print('Name :',fabricated_name,'\nEmail :',fabricated_email)
# Out:
# First Name : Neema Helan
# Last Name : Jaimon
# Name : Neema Helan Jaimon
# Email : nhelanjaimon823@gmail.com

# %%
companies = pd.read_csv('companies_us.csv')
companies = companies[companies['Country'] == 'USA']
companies = companies.drop(['Country','ST'],axis=1)
companies = companies.sample(27880) 
companies = companies.reset_index().drop(['index'],axis=1)

# %%
random_contacts_job = pd.merge(left = random_contacts_final,
                               right = companies,
                               how='right',
                               left_on = 'City',
                               right_on = 'City')
random_contacts_job = random_contacts_job.dropna()
random_contacts_job.sample(45)
# Out:
#                     Name        Occupation        Education Marital Status  \
# 19425     Adele Johnston             Actor  Upper secondary         Single
# 4617       Jessica Lloyd        Astronomer         Bachelor         Single
# 7267      Leonardo Payne         Historian           Master        Married
# 9286      Leonardo Payne         Historian           Master        Married
# 7495      Leonardo Payne         Historian           Master        Married
# 19258   Roland Alexander             Actor  Upper secondary         Single
# 5374     Adelaide Foster        Astronomer         Bachelor        Married
# 22383      Aldus Roberts         Historian  Upper secondary        Married
# 16527        Reid Walker          Botanist  Lower secondary         Single
# 7815      Leonardo Payne         Historian           Master        Married
# 7224      Leonardo Payne         Historian           Master        Married
# ...
